# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('datasets/credit_data_raw.csv')

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
for x in df.columns:
    print(x)
# Out:
# person_age
# person_income
# person_home_ownership
# person_emp_length
# loan_intent
# loan_grade
# loan_amnt
# loan_int_rate
# loan_status
# loan_percent_income
# cb_person_default_on_file
# cb_person_cred_hist_length

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df['person_home_ownership'].value_counts()
# Out:
# RENT        16446
# MORTGAGE    13444
# OWN          2584
# OTHER         107
# Name: person_home_ownership, dtype: int64

# %%
df['loan_intent'].value_counts()
# Out:
# EDUCATION            6453
# MEDICAL              6071
# VENTURE              5719
# PERSONAL             5521
# DEBTCONSOLIDATION    5212
# HOMEIMPROVEMENT      3605
# Name: loan_intent, dtype: int64

# %%
df['loan_grade'].value_counts()
# Out:
# A    10777
# B    10451
# C     6458
# D     3626
# E      964
# F      241
# G       64
# Name: loan_grade, dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# 0    25473
# 1     7108
# Name: loan_status, dtype: int64

# %% [markdown]
# ## Check Missing Value

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %% [markdown]
# ## Check Data Type for Every Columns

# %%
df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df_numerical = df.select_dtypes(exclude='object')
df_categorical = df.select_dtypes(include='object')

# %%
df_numerical.dropna(inplace=True)

# %% [markdown]
# ## Check Data Outlier

# %%
plt.scatter(df['person_age'], df['loan_amnt'], c='blue', alpha=0.5)
plt.xlabel("Person Age")
plt.ylabel("Loan Amount")
plt.show()

# %%
plt.boxplot(x=df['person_age'], vert=False)
plt.xlabel('Person Age')
plt.show()

# %%
plt.boxplot(x=df['person_income'], vert=False)
plt.xlabel('Income')
plt.show()

# %%
plt.boxplot(x=df_numerical['person_emp_length'])
plt.xlabel('Employment length')
plt.show()

# %%
plt.boxplot(x=df_numerical['person_age'])
plt.xlabel('Age')
plt.show()

# %%
plt.scatter(df_numerical['person_age'], df_numerical['person_emp_length'], c='blue', alpha=0.5)
plt.xlabel("Person Age")
plt.ylabel("emp length")
plt.show()

# %% [markdown]
# for i in df_numerical.columns:
#     plt.boxplot(x=df[i],vert=False)
#     plt.xlabel(i)
#     plt.show()

# %% [markdown]
# df_numerical.plot(kind='box', vert=False)

# %%
# Use Pandas to drop the record from the data frame and create a new one
df_new = df_numerical.drop(df_numerical[df_numerical['person_age'] > 100].index)

# Create a scatter plot of age and interest rate
colors = ["blue","red"]
plt.scatter(df_new['person_age'],df_new['loan_int_rate'],
            c = df_new['loan_status'],
            cmap = matplotlib.colors.ListedColormap(colors),
            alpha=0.5)
plt.xlabel("Person Age")
plt.ylabel("Loan Interest Rate")
plt.show()

# %% [markdown]
# ### Handle Missing Data
#
# Generaly there is a three way to handle missing data
# * Replace value where the data is missing
# * Remove the rows that containing missing data
# * Leave the row with missing data unchanged
#
# ![Understand%20the%20data.png](attachment:Understand%20the%20data.png)
